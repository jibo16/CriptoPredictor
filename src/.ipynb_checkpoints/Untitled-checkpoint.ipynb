# %%
import pandas as pd
import numpy as np
import requests
import math
from matplotlib import pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from statsmodels.tsa.ar_model import AR
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.arima_model import ARMA
from statsmodels.tsa.stattools import adfuller
from keras.layers import LSTM, Dense
from tensorflow.keras.models import Sequential
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import acf, pacf
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# Out:
# Using TensorFlow backend.

# %%
url = 'https://min-api.cryptocompare.com/data/v2/histoday?fsym=BTC&tsym=USD&limit=100'

# %%
def call(url):
    ''' 
    funcion que llama a la api de cryptocompare

    '''
    response = requests.get(url)
    read = response.json()
    return read

# %%
def crypto_definer(url):
    ''' Extrae los valores de la crypto y los pega en un dataframe '''
    moneda = call(url)
    high = []
    low = []
    Open=[]
    close = []
    unx_time= []
    for i in moneda['Data']['Data']:
        unx_time.append(i['time'])
        high.append(i['high'])
        low.append(i['low'])
        Open.append(i['open'])
        close.append(i['close'])
    df = pd.DataFrame()
    df['UNIX_TIME'] = unx_time
    df['Open'] = Open
    df['High'] = high
    df['Low'] = low
    df['Close'] = close
    return df

# %%
crypto_definer(url)
# Out:
#       UNIX_TIME     Open      High      Low    Close
# 0    1574208000  8133.57   8232.23  8047.73  8093.60
# 1    1574294400  8093.60   8133.73  7437.33  7632.59
# 2    1574380800  7632.59   7721.90  6815.03  7292.20
# 3    1574467200  7292.20   7368.18  7119.41  7339.24
# 4    1574553600  7339.24   7364.59  6888.89  6930.09
# ..          ...      ...       ...      ...      ...
# 96   1582502400  9977.39  10019.30  9495.76  9664.21
# 97   1582588800  9664.21   9682.05  9258.40  9316.18
# 98   1582675200  9316.18   9379.07  8652.97  8793.50
# 99   1582761600  8793.50   8978.84  8540.74  8821.50
# 100  1582848000  8821.50   8908.80  8449.12  8598.96
#
# [101 rows x 5 columns]

# %%
def convert(url):
    df = crypto_definer(url)
    df['UNIX_TIME'] = df['UNIX_TIME'].astype(int)
    df['UNIX_TIME'] = pd.to_datetime(df['UNIX_TIME'], unit='s')

    return df

# %%
df = convert(url)

# %%
df.isna().sum()
# Out:
# UNIX_TIME    0
# Open         0
# High         0
# Low          0
# Close        0
# dtype: int64

# %% [markdown]
# # Forma grafica de observar que no es estacionaria

# %%
plt.figure(figsize=(12,12))
sns.set()
plt.plot(df['UNIX_TIME'], df['Open'])
plt.plot(df['UNIX_TIME'], df['High'])
plt.plot(df['UNIX_TIME'], df['Low'])
plt.plot(df['UNIX_TIME'], df['Close'])
plt.title('Precio del BTC/USD')
plt.xlabel('Tiempo')
plt.ylabel('Precio')
# Out:
# Text(0, 0.5, 'Precio')

# %% [markdown]
# # Forma estadistica de demostrar que no es estacionaria

# %%
def adf_test(timeseries):
    #Perform Dickey-Fuller test:
    print ('Results of Dickey-Fuller Test:')
    dftest = adfuller(timeseries, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
       dfoutput['Critical Value (%s)'%key] = value
    print (dfoutput)
    
adf_test(df['Open'])
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                 -0.902773
# p-value                         0.787058
# Lags Used                       1.000000
# Number of Observations Used    99.000000
# Critical Value (1%)            -3.498198
# Critical Value (5%)            -2.891208
# Critical Value (10%)           -2.582596
# dtype: float64

# %%
adf_test(df['High'])
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -0.958123
# p-value                          0.768230
# Lags Used                        0.000000
# Number of Observations Used    100.000000
# Critical Value (1%)             -3.497501
# Critical Value (5%)             -2.890906
# Critical Value (10%)            -2.582435
# dtype: float64

# %%
adf_test(df['Low'])
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -1.026776
# p-value                          0.743373
# Lags Used                        0.000000
# Number of Observations Used    100.000000
# Critical Value (1%)             -3.497501
# Critical Value (5%)             -2.890906
# Critical Value (10%)            -2.582435
# dtype: float64

# %%
adf_test(df['Close'])
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                 -0.995358
# p-value                         0.754954
# Lags Used                       1.000000
# Number of Observations Used    99.000000
# Critical Value (1%)            -3.498198
# Critical Value (5%)            -2.891208
# Critical Value (10%)           -2.582596
# dtype: float64

# %%
df = df.rename(columns={'UNIX_TIME': 'Date'})
df
# Out:
#           Date     Open      High      Low    Close
# 0   2019-11-20  8133.57   8232.23  8047.73  8093.60
# 1   2019-11-21  8093.60   8133.73  7437.33  7632.59
# 2   2019-11-22  7632.59   7721.90  6815.03  7292.20
# 3   2019-11-23  7292.20   7368.18  7119.41  7339.24
# 4   2019-11-24  7339.24   7364.59  6888.89  6930.09
# ..         ...      ...       ...      ...      ...
# 96  2020-02-24  9977.39  10019.30  9495.76  9664.21
# 97  2020-02-25  9664.21   9682.05  9258.40  9316.18
# 98  2020-02-26  9316.18   9379.07  8652.97  8793.50
# 99  2020-02-27  8793.50   8978.84  8540.74  8821.50
# 100 2020-02-28  8821.50   8908.80  8449.12  8598.96
#
# [101 rows x 5 columns]

# %%
df = df.set_index('Date')

# %%
df
# Out:
#                Open      High      Low    Close
# Date
# 2019-11-20  8133.57   8232.23  8047.73  8093.60
# 2019-11-21  8093.60   8133.73  7437.33  7632.59
# 2019-11-22  7632.59   7721.90  6815.03  7292.20
# 2019-11-23  7292.20   7368.18  7119.41  7339.24
# 2019-11-24  7339.24   7364.59  6888.89  6930.09
# ...             ...       ...      ...      ...
# 2020-02-24  9977.39  10019.30  9495.76  9664.21
# 2020-02-25  9664.21   9682.05  9258.40  9316.18
# 2020-02-26  9316.18   9379.07  8652.97  8793.50
# 2020-02-27  8793.50   8978.84  8540.74  8821.50
# 2020-02-28  8821.50   8908.80  8449.12  8598.96
#
# [101 rows x 4 columns]

# %% [markdown]
# bajo el test dicky fueller
# ya que el test statistic es mayor que el critical value, podemos definir que la serie de tiempo no es estacionaria, por lo que podemos confirmar que los datos no son estacionales

# %%
def clean(columna):
    new_df = pd.DataFrame(df[columna],df.index)
    return new_df


open_df = clean('Open')

# %%
open_df
# Out:
#                Open
# Date
# 2019-11-20  8133.57
# 2019-11-21  8093.60
# 2019-11-22  7632.59
# 2019-11-23  7292.20
# 2019-11-24  7339.24
# ...             ...
# 2020-02-24  9977.39
# 2020-02-25  9664.21
# 2020-02-26  9316.18
# 2020-02-27  8793.50
# 2020-02-28  8821.50
#
# [101 rows x 1 columns]

# %% [markdown]
# # Convirtiendo las series a estacionales

# %%
from statsmodels.tsa.stattools import adfuller
def test_stationarity(timeseries):
    
    #Determing rolling statistics
    rolmean = timeseries.rolling(window=12).mean()
    rolstd = timeseries.rolling(window=12).std()

    #Plot rolling statistics:
    plt.figure(figsize=(12,12))
    orig = plt.plot(timeseries, color='blue',label='Original')
    mean = plt.plot(rolmean, color='red', label='Rolling Mean')
    std = plt.plot(rolstd, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.savefig('RollingMeanStd')
    plt.show(block=False)
    
    #Perform Dickey-Fuller test:
    print ('Results of Dickey-Fuller Test:')
    dftest = adfuller(timeseries, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print (dfoutput)
    
    
    
test_stationarity(open_df['Open'])
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                 -0.902773
# p-value                         0.787058
# #Lags Used                      1.000000
# Number of Observations Used    99.000000
# Critical Value (1%)            -3.498198
# Critical Value (5%)            -2.891208
# Critical Value (10%)           -2.582596
# dtype: float64

# %%
df
# Out:
#                Open      High      Low    Close
# Date
# 2019-11-20  8133.57   8232.23  8047.73  8093.60
# 2019-11-21  8093.60   8133.73  7437.33  7632.59
# 2019-11-22  7632.59   7721.90  6815.03  7292.20
# 2019-11-23  7292.20   7368.18  7119.41  7339.24
# 2019-11-24  7339.24   7364.59  6888.89  6930.09
# ...             ...       ...      ...      ...
# 2020-02-24  9977.39  10019.30  9495.76  9664.21
# 2020-02-25  9664.21   9682.05  9258.40  9316.18
# 2020-02-26  9316.18   9379.07  8652.97  8793.50
# 2020-02-27  8793.50   8978.84  8540.74  8821.50
# 2020-02-28  8821.50   8908.80  8449.12  8598.96
#
# [101 rows x 4 columns]

# %%
ts_log = np.log(df)

# %%
plt.plot(ts_log['High'])

# %%
df['Open'] = df['Open'] - df['Open'].shift(1)
df = df.dropna()

# %%
df.head()
# Out:
#               Open     High      Low    Close
# Date
# 2019-11-21  -39.97  8133.73  7437.33  7632.59
# 2019-11-22 -461.01  7721.90  6815.03  7292.20
# 2019-11-23 -340.39  7368.18  7119.41  7339.24
# 2019-11-24   47.04  7364.59  6888.89  6930.09
# 2019-11-25 -409.15  7386.06  6560.13  7138.23

# %%
df['Open'].plot()

# %%
moving_avg = df['Open'].rolling(12).mean()
plt.figure(figsize=(12,12))
plt.plot(df['Open'])
plt.plot(moving_avg, color='red')

# %%
test_stationarity(df['Open'])
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -1.138730e+01
# p-value                        8.230018e-21
# #Lags Used                     0.000000e+00
# Number of Observations Used    9.900000e+01
# Critical Value (1%)           -3.498198e+00
# Critical Value (5%)           -2.891208e+00
# Critical Value (10%)          -2.582596e+00
# dtype: float64

# %%
ts_log_diff = ts_log['Open'] - ts_log['Open'].shift()
plt.plot(ts_log_diff);

# %%
ts_log_diff.dropna(inplace=True)
test_stationarity(ts_log_diff)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -1.138180e+01
# p-value                        8.475670e-21
# #Lags Used                     0.000000e+00
# Number of Observations Used    9.900000e+01
# Critical Value (1%)           -3.498198e+00
# Critical Value (5%)           -2.891208e+00
# Critical Value (10%)          -2.582596e+00
# dtype: float64

# %%
decomposition = seasonal_decompose(ts_log['Open'])

trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid
plt.figure(figsize=(12,12))
plt.subplot(411)
plt.plot(ts_log)
plt.legend(loc='best')
plt.subplot(412)
plt.plot(trend, label='Trend')
plt.legend(loc='best')
plt.subplot(413)
plt.plot(seasonal,label='Seasonality')
plt.legend(loc='best')
plt.subplot(414)
plt.plot(residual, label='Residuals')
plt.legend(loc='best')
plt.tight_layout()
# Out:
# No handles with labels found to put in legend.

# %%
ts_log_decompose = residual
ts_log_decompose.dropna(inplace=True)
test_stationarity(ts_log_decompose)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -7.619945e+00
# p-value                        2.141662e-11
# #Lags Used                     4.000000e+00
# Number of Observations Used    9.000000e+01
# Critical Value (1%)           -3.505190e+00
# Critical Value (5%)           -2.894232e+00
# Critical Value (10%)          -2.584210e+00
# dtype: float64

# %%
lag_acf = acf(ts_log_diff, nlags=20)
lag_pacf = pacf(ts_log_diff, nlags=20, method='ols')

# %%
plt.figure(figsize=(12,12))
plt.subplot(121) 
plt.plot(lag_acf)
plt.axhline(y=0,linestyle='--',color='gray')
plt.axhline(y=-1.96/np.sqrt(len(ts_log_diff)),linestyle='--',color='gray')
plt.axhline(y=1.96/np.sqrt(len(ts_log_diff)),linestyle='--',color='gray')
plt.title('Autocorrelation Function')
# Out:
# Text(0.5, 1.0, 'Autocorrelation Function')

# %%
plt.subplot(122)
plt.plot(lag_pacf)
plt.axhline(y=0,linestyle='--',color='gray')
plt.axhline(y=-1.96/np.sqrt(len(ts_log_diff)),linestyle='--',color='gray')
plt.axhline(y=1.96/np.sqrt(len(ts_log_diff)),linestyle='--',color='gray')
plt.title('Partial Autocorrelation Function')
plt.tight_layout()

# %%
model = ARIMA(ts_log['Open'], order=(25, 1, 0))  
results_AR = model.fit(disp=-1)  
plt.plot(ts_log_diff)
plt.plot(results_AR.fittedvalues, color='red')
plt.savefig('armiader.png')
plt.title('RSS: %.4f'% sum((results_AR.fittedvalues-ts_log_diff)**2))

# %%
model = ARIMA(ts_log['Open'], order=(0, 1, 21))  
results_MA = model.fit(disp=-1)  
plt.plot(ts_log_diff)
plt.plot(results_MA.fittedvalues, color='red')
plt.title('RSS: %.4f'% sum((results_MA.fittedvalues-ts_log_diff)**2))
plt.savefig('arimaizq.png')

# %%
model = ARIMA(ts_log['Open'], order=(24, 1, 20))  
results_ARIMA = model.fit(disp=-1)  
plt.plot(ts_log_diff)
plt.plot(results_ARIMA.fittedvalues, color='red')
plt.savefig('figura1.png')
plt.title('RSS: %.4f'% sum((results_ARIMA.fittedvalues-ts_log_diff)**2))
