# %%
import pandas as pd
import numpy as np
import requests
import math
from scipy import stats
from matplotlib import pyplot as plt
from sklearn.metrics import mean_squared_error 
from sklearn.metrics import mean_absolute_error
from statsmodels.tsa.arima_model import ARMA
from statsmodels.tsa.stattools import grangercausalitytests
from statsmodels.tsa.stattools import adfuller
from keras.layers import LSTM, Dense
from tensorflow.keras.models import Sequential
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import acf, pacf
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import statsmodels.tsa.api as smt
from statsmodels.tsa.api import VAR
from statsmodels.stats.stattools import durbin_watson
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# Out:
# Using TensorFlow backend.

# %%
DAX = pd.read_csv('../Data/DAX.csv')
VOO = pd.read_csv('../Data/VOO.csv')

# %%
DAX
# Out:
#            Date       Open       High        Low      Close  Adj Close  Volume
# 0    2019-03-04  25.910000  25.910000  25.612000  25.700001  25.041664    2800
# 1    2019-03-05  25.731001  25.731001  25.700001  25.700001  25.041664     500
# 2    2019-03-06  25.780001  25.780001  25.650000  25.660000  25.002687     700
# 3    2019-03-07  25.240000  25.299999  25.230000  25.231001  24.584679    7400
# 4    2019-03-08  25.191000  25.191000  25.191000  25.191000  24.545704     400
# ..          ...        ...        ...        ...        ...        ...     ...
# 249  2020-02-27  25.620001  26.003000  25.209999  25.209999  25.209999   10700
# 250  2020-02-28  24.510000  24.995001  24.473000  24.950001  24.950001    6400
# 251  2020-03-02  25.090000  25.420000  24.905001  25.360001  25.360001    3600
# 252  2020-03-03  25.719999  25.750000  25.000000  25.091000  25.091000    4900
# 253  2020-03-04  25.570000  25.610001  25.570000  25.610001  25.610001     465
#
# [254 rows x 7 columns]

# %%
VOO
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2019-03-04  258.869995  259.100006  254.490005  256.839996  251.658798
# 1    2019-03-05  256.989990  257.170013  255.960007  256.540009  251.364868
# 2    2019-03-06  256.619995  256.619995  254.600006  254.899994  249.757950
# 3    2019-03-07  254.479996  254.600006  251.949997  252.850006  247.749298
# 4    2019-03-08  250.880005  252.449997  250.339996  252.339996  247.249573
# ..          ...         ...         ...         ...         ...         ...
# 249  2020-02-27  280.570007  284.480011  273.359985  273.390015  273.390015
# 250  2020-02-28  265.320007  272.920013  262.250000  271.739990  271.739990
# 251  2020-03-02  274.000000  284.040009  270.489990  283.869995  283.869995
# 252  2020-03-03  284.339996  288.320007  273.359985  276.040009  276.040009
# 253  2020-03-04  281.230011  282.299988  278.700012  280.378998  280.378998
#
#        Volume
# 0     3384200
# 1     2475900
# 2     2514900
# 3     6441200
# 4     4522300
# ..        ...
# 249  14897000
# 250  23324100
# 251  12428600
# 252   9766400
# 253   1646382
#
# [254 rows x 7 columns]

# %%
DAX['Date'] = pd.to_datetime(DAX['Date'])
DAX
# Out:
#           Date       Open       High        Low      Close  Adj Close  Volume
# 0   2019-03-04  25.910000  25.910000  25.612000  25.700001  25.041664    2800
# 1   2019-03-05  25.731001  25.731001  25.700001  25.700001  25.041664     500
# 2   2019-03-06  25.780001  25.780001  25.650000  25.660000  25.002687     700
# 3   2019-03-07  25.240000  25.299999  25.230000  25.231001  24.584679    7400
# 4   2019-03-08  25.191000  25.191000  25.191000  25.191000  24.545704     400
# ..         ...        ...        ...        ...        ...        ...     ...
# 249 2020-02-27  25.620001  26.003000  25.209999  25.209999  25.209999   10700
# 250 2020-02-28  24.510000  24.995001  24.473000  24.950001  24.950001    6400
# 251 2020-03-02  25.090000  25.420000  24.905001  25.360001  25.360001    3600
# 252 2020-03-03  25.719999  25.750000  25.000000  25.091000  25.091000    4900
# 253 2020-03-04  25.570000  25.610001  25.570000  25.610001  25.610001     465
#
# [254 rows x 7 columns]

# %%
VOO['Date'] = pd.to_datetime(VOO['Date'])
VOO
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 0   2019-03-04  258.869995  259.100006  254.490005  256.839996  251.658798
# 1   2019-03-05  256.989990  257.170013  255.960007  256.540009  251.364868
# 2   2019-03-06  256.619995  256.619995  254.600006  254.899994  249.757950
# 3   2019-03-07  254.479996  254.600006  251.949997  252.850006  247.749298
# 4   2019-03-08  250.880005  252.449997  250.339996  252.339996  247.249573
# ..         ...         ...         ...         ...         ...         ...
# 249 2020-02-27  280.570007  284.480011  273.359985  273.390015  273.390015
# 250 2020-02-28  265.320007  272.920013  262.250000  271.739990  271.739990
# 251 2020-03-02  274.000000  284.040009  270.489990  283.869995  283.869995
# 252 2020-03-03  284.339996  288.320007  273.359985  276.040009  276.040009
# 253 2020-03-04  281.230011  282.299988  278.700012  280.378998  280.378998
#
#        Volume
# 0     3384200
# 1     2475900
# 2     2514900
# 3     6441200
# 4     4522300
# ..        ...
# 249  14897000
# 250  23324100
# 251  12428600
# 252   9766400
# 253   1646382
#
# [254 rows x 7 columns]

# %%
plt.figure(figsize=(16,12))
ax = plt.axes()
ax.set_facecolor('grey')
ax.set_title('DAX Open Price',fontsize=20)
ax = DAX['Open'].plot(grid=True, color='red')
plt.savefig('../images/DAX_open_price.png')

# %%
# Plot de los datos de DAX
fig, axes = plt.subplots(nrows=2,ncols=2, figsize=(12,12))
axes[0,0].plot(DAX['Date'], DAX['Open'])
axes[0,0].set_title('Open Price')
axes[0,1].plot(DAX['Date'],DAX['High'], color='red')
axes[0,1].set_title('High price')
axes[1,0].plot(DAX['Date'], DAX['Low'], color='green')
axes[1,0].set_title('Low Price')
axes[1,1].plot(DAX['Date'],DAX['Close'], color='purple')
axes[1,1].set_title('Close Price')
plt.savefig('../images/DAXOriginal.png')
plt.show()

# %%
plt.figure(figsize=(16,12))
ax = plt.axes()
ax.set_facecolor('grey')
ax.set_title('VOO Open Price',fontsize=20)
ax = VOO['Open'].plot(grid=True, color='purple')
plt.savefig('../images/VOO_open_price.png')

# %%
# plot de los datos de VOO
fig, axes = plt.subplots(nrows=2,ncols=2, figsize=(12,12))
axes[0,0].plot(VOO['Date'], VOO['Open'])
axes[0,0].set_title('Open Price')
axes[0,1].plot(VOO['Date'],VOO['High'], color='red')
axes[0,1].set_title('High price')
axes[1,0].plot(VOO['Date'], VOO['Low'], color='green')
axes[1,0].set_title('Low Price')
axes[1,1].plot(VOO['Date'],VOO['Close'], color='purple')
axes[1,1].set_title('Close Price')
plt.savefig('../images/VOO_Original.png')
plt.show()

# %%
# Muestra si el datase es una distribucion normal, si el pvalue es mayor que el 5% entonces la distribucion no es normal
def norm_dist(tested):
    nh = 0.05
    Stats, p = stats.normaltest(tested)
    print('Statistic: ', Stats, 'Pvalue: ', p)
    if p > nh:
        return 'El dataset es una distribucion normal'
    else:
        return 'El dataset no es una distribucion normal'

# %%
norm_dist(DAX['Open'])
# Out:
# Statistic:  34.676928898442306 Pvalue:  2.9512130662629512e-08
# 'El dataset no es una distribucion normal'

# %%
norm_dist(VOO['Open'])
# Out:
# Statistic:  21.240197536841993 Pvalue:  2.442022761647952e-05
# 'El dataset no es una distribucion normal'

# %%
# Ploteo de el histograma de los datos, donde se muestra la concentracion principal de precios y 
# los cuantiles teoricos que ademas muestran la con una linea roja la mejor opcion de prediccion para los datos
plt.figure(figsize=(12,12))
plt.subplot(1,2,1)
DAX['Open'].hist(bins=50)
plt.title('Open Price')
plt.subplot(1,2,2)
stats.probplot(DAX['Open'],plot=plt)
plt.savefig('../images/DAXHistProb.png')
plt.show()

# %%
# plot de concentracion de los precios y un plot de la probabilidad con 
plt.figure(figsize=(12,12))
plt.subplot(1,2,1)
VOO['Open'].hist(bins=50)
plt.title('Open Price')
plt.subplot(1,2,2)
stats.probplot(VOO['Open'],plot=plt)
plt.savefig('../images/VOOHistProb.png')
plt.show()

# %%
# Muestra la correlacion y la correlacion parcial de los datos para DAX
fig, axes = plt.subplots(2,figsize=(12,12))
axes[0] = plot_acf(DAX['Open'], ax=axes[0])
axes[1] = plot_pacf(DAX['Open'], ax=axes[1])
plt.savefig('../images/DAXPartAutocorr.png')

# %%
# Autocorrelacion y correlacion parcial de los datos de VOO
fig, axes = plt.subplots(2,figsize=(12,12))
axes[0] = plot_acf(VOO['Open'], ax=axes[0])
axes[1] = plot_pacf(VOO['Open'], ax=axes[1])
plt.savefig('../images/VOOPartAutocorr.png')

# %%
# definiendo el training y el test para DAX
X_train_DAX, X_test_DAX = DAX[0:-15], DAX[-15:]

# %%
# definiendo el training y el test para VOO
X_train_VOO, X_test_VOO = VOO[0:-15], VOO[-15:]

# %%
print('Train shape: ', X_train_DAX.shape, 'Test shape: ', X_test_DAX.shape)
# Out:
# Train shape:  (239, 7) Test shape:  (15, 7)

# %%
# Convirtiendo los datos a estacionarios para DAX
transform_data_DAX = DAX[['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']].diff().dropna()
transform_data_DAX
# Out:
#          Open      High       Low     Close  Adj Close  Volume
# 1   -0.178999 -0.178999  0.088001  0.000000   0.000000 -2300.0
# 2    0.049000  0.049000 -0.050001 -0.040001  -0.038977   200.0
# 3   -0.540001 -0.480002 -0.420000 -0.428999  -0.418008  6700.0
# 4   -0.049000 -0.108999 -0.039000 -0.040001  -0.038975 -7000.0
# 5    0.149000  0.153999  0.139999  0.149000   0.145182  2100.0
# ..        ...       ...       ...       ...        ...     ...
# 249 -0.639999 -0.461001 -0.890001 -0.960001  -0.960001  7400.0
# 250 -1.110001 -1.007999 -0.736999 -0.259998  -0.259998 -4300.0
# 251  0.580000  0.424999  0.432001  0.410000   0.410000 -2800.0
# 252  0.629999  0.330000  0.094999 -0.269001  -0.269001  1300.0
# 253 -0.149999 -0.139999  0.570000  0.519001   0.519001 -4435.0
#
# [253 rows x 6 columns]

# %%
# Convirtiendo los datos a estacionarios para VOO
transform_data_VOO = VOO[['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']].diff().dropna()
transform_data_VOO
# Out:
#           Open       High        Low      Close  Adj Close      Volume
# 1    -1.880005  -1.929993   1.470002  -0.299987  -0.293930   -908300.0
# 2    -0.369995  -0.550018  -1.360001  -1.640015  -1.606918     39000.0
# 3    -2.139999  -2.019989  -2.650009  -2.049988  -2.008652   3926300.0
# 4    -3.599991  -2.150009  -1.610001  -0.510010  -0.499725  -1918900.0
# 5     2.159988   3.669998   2.680008   3.679993   3.605774  -2638100.0
# ..         ...        ...        ...        ...        ...         ...
# 249  -8.039978  -7.799988 -12.120026 -12.679992 -12.679992   4663300.0
# 250 -15.250000 -11.559998 -11.109985  -1.650025  -1.650025   8427100.0
# 251   8.679993  11.119996   8.239990  12.130005  12.130005 -10895500.0
# 252  10.339996   4.279998   2.869995  -7.829986  -7.829986  -2662200.0
# 253  -3.109985  -6.020019   5.340027   4.338989   4.338989  -8120018.0
#
# [253 rows x 6 columns]

# %%
# agregando la columan fecha para los dato de DAX
concat_data_DAX = transform_data_DAX.join(DAX['Date'])
concat_data_DAX
# Out:
#          Open      High       Low     Close  Adj Close  Volume       Date
# 1   -0.178999 -0.178999  0.088001  0.000000   0.000000 -2300.0 2019-03-05
# 2    0.049000  0.049000 -0.050001 -0.040001  -0.038977   200.0 2019-03-06
# 3   -0.540001 -0.480002 -0.420000 -0.428999  -0.418008  6700.0 2019-03-07
# 4   -0.049000 -0.108999 -0.039000 -0.040001  -0.038975 -7000.0 2019-03-08
# 5    0.149000  0.153999  0.139999  0.149000   0.145182  2100.0 2019-03-11
# ..        ...       ...       ...       ...        ...     ...        ...
# 249 -0.639999 -0.461001 -0.890001 -0.960001  -0.960001  7400.0 2020-02-27
# 250 -1.110001 -1.007999 -0.736999 -0.259998  -0.259998 -4300.0 2020-02-28
# 251  0.580000  0.424999  0.432001  0.410000   0.410000 -2800.0 2020-03-02
# 252  0.629999  0.330000  0.094999 -0.269001  -0.269001  1300.0 2020-03-03
# 253 -0.149999 -0.139999  0.570000  0.519001   0.519001 -4435.0 2020-03-04
#
# [253 rows x 7 columns]

# %%
# Reorganizando las columnas para DAX
concat_data_DAX = concat_data_DAX[['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']]
concat_data_DAX
# Out:
#           Date      Open      High       Low     Close  Adj Close  Volume
# 1   2019-03-05 -0.178999 -0.178999  0.088001  0.000000   0.000000 -2300.0
# 2   2019-03-06  0.049000  0.049000 -0.050001 -0.040001  -0.038977   200.0
# 3   2019-03-07 -0.540001 -0.480002 -0.420000 -0.428999  -0.418008  6700.0
# 4   2019-03-08 -0.049000 -0.108999 -0.039000 -0.040001  -0.038975 -7000.0
# 5   2019-03-11  0.149000  0.153999  0.139999  0.149000   0.145182  2100.0
# ..         ...       ...       ...       ...       ...        ...     ...
# 249 2020-02-27 -0.639999 -0.461001 -0.890001 -0.960001  -0.960001  7400.0
# 250 2020-02-28 -1.110001 -1.007999 -0.736999 -0.259998  -0.259998 -4300.0
# 251 2020-03-02  0.580000  0.424999  0.432001  0.410000   0.410000 -2800.0
# 252 2020-03-03  0.629999  0.330000  0.094999 -0.269001  -0.269001  1300.0
# 253 2020-03-04 -0.149999 -0.139999  0.570000  0.519001   0.519001 -4435.0
#
# [253 rows x 7 columns]

# %%
# agregando la columan de fechas
concat_data_VOO = transform_data_VOO.join(VOO['Date'])
concat_data_VOO
# Out:
#           Open       High        Low      Close  Adj Close      Volume  \
# 1    -1.880005  -1.929993   1.470002  -0.299987  -0.293930   -908300.0
# 2    -0.369995  -0.550018  -1.360001  -1.640015  -1.606918     39000.0
# 3    -2.139999  -2.019989  -2.650009  -2.049988  -2.008652   3926300.0
# 4    -3.599991  -2.150009  -1.610001  -0.510010  -0.499725  -1918900.0
# 5     2.159988   3.669998   2.680008   3.679993   3.605774  -2638100.0
# ..         ...        ...        ...        ...        ...         ...
# 249  -8.039978  -7.799988 -12.120026 -12.679992 -12.679992   4663300.0
# 250 -15.250000 -11.559998 -11.109985  -1.650025  -1.650025   8427100.0
# 251   8.679993  11.119996   8.239990  12.130005  12.130005 -10895500.0
# 252  10.339996   4.279998   2.869995  -7.829986  -7.829986  -2662200.0
# 253  -3.109985  -6.020019   5.340027   4.338989   4.338989  -8120018.0
#
#           Date
# 1   2019-03-05
# 2   2019-03-06
# 3   2019-03-07
# 4   2019-03-08
# 5   2019-03-11
# ..         ...
# 249 2020-02-27
# 250 2020-02-28
# 251 2020-03-02
# 252 2020-03-03
# 253 2020-03-04
#
# [253 rows x 7 columns]

# %%
# Organizando las columnas
concat_data_VOO = concat_data_VOO[['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']]
concat_data_VOO
# Out:
#           Date       Open       High        Low      Close  Adj Close  \
# 1   2019-03-05  -1.880005  -1.929993   1.470002  -0.299987  -0.293930
# 2   2019-03-06  -0.369995  -0.550018  -1.360001  -1.640015  -1.606918
# 3   2019-03-07  -2.139999  -2.019989  -2.650009  -2.049988  -2.008652
# 4   2019-03-08  -3.599991  -2.150009  -1.610001  -0.510010  -0.499725
# 5   2019-03-11   2.159988   3.669998   2.680008   3.679993   3.605774
# ..         ...        ...        ...        ...        ...        ...
# 249 2020-02-27  -8.039978  -7.799988 -12.120026 -12.679992 -12.679992
# 250 2020-02-28 -15.250000 -11.559998 -11.109985  -1.650025  -1.650025
# 251 2020-03-02   8.679993  11.119996   8.239990  12.130005  12.130005
# 252 2020-03-03  10.339996   4.279998   2.869995  -7.829986  -7.829986
# 253 2020-03-04  -3.109985  -6.020019   5.340027   4.338989   4.338989
#
#          Volume
# 1     -908300.0
# 2       39000.0
# 3     3926300.0
# 4    -1918900.0
# 5    -2638100.0
# ..          ...
# 249   4663300.0
# 250   8427100.0
# 251 -10895500.0
# 252  -2662200.0
# 253  -8120018.0
#
# [253 rows x 7 columns]

# %%
""" checando que los datos son estacionarios con el test de adfuller, 
si el pvalue es mayor que el 5% entonces no lo son """
def adfull(dataset):
    nh = 0.05
    test = adfuller(dataset, autolag='AIC')
    output = {'test statistic: ': test[0], 'pvalue': test[1], 'used lag: ': test[2], 'Number of observations': test[3]}
    print(output)
    if test[1] > nh:
        return 'Los datos no son estacionarios, ya que el pvalue es mayor al 5% ' 
    return 'Los datos son estacionarios'


adfull(concat_data_DAX['Open'])
# Out:
# {'test statistic: ': -16.159480031410315, 'pvalue': 4.4815355034769035e-29, 'used lag: ': 0, 'Number of observations': 252}
# 'Los datos son estacionarios'

# %%
adfull(concat_data_VOO['Open'])
# Out:
# {'test statistic: ': -15.091663358099725, 'pvalue': 8.176547948250737e-28, 'used lag: ': 0, 'Number of observations': 252}
# 'Los datos son estacionarios'

# %% [markdown]
# # Plot de los datos

# %%
# stationary data plot
plt.figure(figsize=(16,12))
ax = plt.axes()
ax.set_facecolor('grey')
ax.set_title('DAX stationary data', fontsize=20)
ax = concat_data_DAX['Open'].plot(grid=True, color='purple', label='Open price')
ax.legend(loc='upper left')
plt.savefig('../images/DAX_stationary_data.png')

# %%
# plot de los datos estacionarios para DAX
fig, axes = plt.subplots(2,2, figsize=(12,12))
axes[0,0].plot(concat_data_DAX['Date'], concat_data_DAX['Open'])
axes[0,0].set_title('Open Stat')
axes[0,1].plot(concat_data_DAX['Date'], concat_data_DAX['High'], color='red')
axes[0,1].set_title('High Price')
axes[1,0].plot(concat_data_DAX['Date'], concat_data_DAX['Low'], color='green')
axes[1,0].set_title('Low Price')
axes[1,1].plot(concat_data_DAX['Date'],concat_data_DAX['Close'], color='purple')
axes[1,1].set_title('Close Price')
plt.savefig('../images/DAXStatdata.png')

# %%
# plot de grafica de VOO
plt.figure(figsize=(16,12))
ax = plt.axes()
ax.set_facecolor('grey')
ax.set_title('VOO stationary data', fontsize=20)
ax = concat_data_VOO['Open'].plot(grid=True, color='black', label='Open price')
ax.legend(loc='upper left')
plt.savefig('../images/VOO_stationary_data.png')
plt.show();

# %%
# plot de los datos estacionarios para VOO
fig, axes = plt.subplots(2,2, figsize=(12,12))
axes[0,0].plot(concat_data_VOO['Date'], concat_data_VOO['Open'])
axes[0,0].set_title('Open Stat')
axes[0,1].plot(concat_data_VOO['Date'], concat_data_VOO['High'],color='red')
axes[0,1].set_title('High Price')
axes[1,0].plot(concat_data_VOO['Date'], concat_data_VOO['Low'],color='green')
axes[1,0].set_title('Low Price')
axes[1,1].plot(concat_data_VOO['Date'],concat_data_VOO['Close'],color='purple')
axes[1,1].set_title('Close Price')
plt.savefig('../images/VOOStatdata.png')

# %%
concat_data_VOO
# Out:
#           Date       Open       High        Low      Close  Adj Close  \
# 1   2019-03-05  -1.880005  -1.929993   1.470002  -0.299987  -0.293930
# 2   2019-03-06  -0.369995  -0.550018  -1.360001  -1.640015  -1.606918
# 3   2019-03-07  -2.139999  -2.019989  -2.650009  -2.049988  -2.008652
# 4   2019-03-08  -3.599991  -2.150009  -1.610001  -0.510010  -0.499725
# 5   2019-03-11   2.159988   3.669998   2.680008   3.679993   3.605774
# ..         ...        ...        ...        ...        ...        ...
# 249 2020-02-27  -8.039978  -7.799988 -12.120026 -12.679992 -12.679992
# 250 2020-02-28 -15.250000 -11.559998 -11.109985  -1.650025  -1.650025
# 251 2020-03-02   8.679993  11.119996   8.239990  12.130005  12.130005
# 252 2020-03-03  10.339996   4.279998   2.869995  -7.829986  -7.829986
# 253 2020-03-04  -3.109985  -6.020019   5.340027   4.338989   4.338989
#
#          Volume
# 1     -908300.0
# 2       39000.0
# 3     3926300.0
# 4    -1918900.0
# 5    -2638100.0
# ..          ...
# 249   4663300.0
# 250   8427100.0
# 251 -10895500.0
# 252  -2662200.0
# 253  -8120018.0
#
# [253 rows x 7 columns]

# %%
concat_data_DAX = concat_data_DAX.set_index('Date')
concat_data_VOO = concat_data_VOO.set_index('Date')

# %% [markdown]
# # Train, test y test de causalidad de grangers

# %%
X_train_DAX = X_train_DAX.set_index('Date')

# %%
X_train_VOO = X_train_VOO.set_index('Date')

# %%
# Aplicando el test de causalidad de granger para ver si los datos se relacionan con su pasado
maxlag=12
def grangers_causation_matrix(data, variables, test='ssr_chi2test', verbose=False):    
    df = pd.DataFrame(np.zeros((len(variables), len(variables))), columns=variables, index=variables)
    for c in df.columns:
        for r in df.index:
            test_result = grangercausalitytests(data[[r, c]], maxlag=maxlag, verbose=False)
            p_values = [round(test_result[i+1][0][test][1],4) for i in range(maxlag)]
            if verbose: print(f'Y = {r}, X = {c}, P Values = {p_values}')
            min_p_value = np.min(p_values)
            df.loc[r, c] = min_p_value
    df.columns = [var + '_x' for var in variables]
    df.index = [var + '_y' for var in variables]
    return df

grangers_causation_matrix(concat_data_DAX, variables = concat_data_DAX.columns)
# Out:
#              Open_x  High_x   Low_x  Close_x  Adj Close_x  Volume_x
# Open_y       1.0000  0.0657  0.0000   0.0000       0.0000    0.0641
# High_y       0.0016  1.0000  0.0000   0.0000       0.0001    0.1917
# Low_y        0.0521  0.0241  1.0000   0.0700       0.0404    0.0572
# Close_y      0.0003  0.0296  0.0000   1.0000       0.4655    0.1157
# Adj Close_y  0.0032  0.1198  0.0003   0.3943       1.0000    0.0997
# Volume_y     0.2989  0.2240  0.2351   0.4362       0.4263    1.0000

# %%
grangers_causation_matrix(concat_data_VOO, variables=concat_data_VOO.columns)
# Out:
#              Open_x  High_x   Low_x  Close_x  Adj Close_x  Volume_x
# Open_y       1.0000  0.0000  0.0000   0.0000        0.000    0.0000
# High_y       0.0011  1.0000  0.0000   0.0000        0.000    0.0070
# Low_y        0.0003  0.0008  1.0000   0.0000        0.000    0.1057
# Close_y      0.1035  0.0002  0.0130   1.0000        0.288    0.0615
# Adj Close_y  0.1210  0.0004  0.0314   0.2926        1.000    0.0800
# Volume_y     0.0000  0.0002  0.0001   0.0000        0.000    1.0000

# %% [markdown]
# # SMT Var prediction DAX

# %%
# El volumen es inverso a los valores de precio en los datos
mod_DAX = smt.VAR(concat_data_DAX)
res_DAX = mod_DAX.fit(maxlags=3)
print(res_DAX.summary())
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Thu, 05, Mar, 2020
# Time:                     16:02:40
# --------------------------------------------------------------------
# No. of Equations:         6.00000    BIC:                   -1.10571
# Nobs:                     250.000    HQIC:                  -2.06521
# Log likelihood:          -1675.47    FPE:                  0.0665545
# AIC:                     -2.71150    Det(Omega_mle):       0.0428848
# --------------------------------------------------------------------
# Results for equation Open
# ===============================================================================
#                   coefficient       std. error           t-stat            prob
# -------------------------------------------------------------------------------
# const                0.000622         0.016053            0.039           0.969
# L1.Open             -0.083201         0.213444           -0.390           0.697
# L1.High             -0.782193         0.215237           -3.634           0.000
# L1.Low              -0.080438         0.202817           -0.397           0.692
# L1.Close             0.410523         0.408762            1.004           0.315
# L1.Adj Close         0.616372         0.372121            1.656           0.098
# L1.Volume            0.000001         0.000001            0.773           0.440
# L2.Open              0.217573         0.227081            0.958           0.338
# L2.High             -0.765633         0.244283           -3.134           0.002
# L2.Low              -0.397162         0.228389           -1.739           0.082
# L2.Close             0.430499         0.417568            1.031           0.303
# L2.Adj Close         0.547766         0.378530            1.447           0.148
# L2.Volume           -0.000000         0.000001           -0.004           0.997
# L3.Open              0.152343         0.203189            0.750           0.453
# L3.High             -0.557738         0.226451           -2.463           0.014
# L3.Low              -0.054934         0.199649           -0.275           0.783
# L3.Close             0.732415         0.410587            1.784           0.074
# L3.Adj Close        -0.200912         0.378341           -0.531           0.595
# L3.Volume           -0.000001         0.000001           -0.442           0.659
# ===============================================================================
#
# Results for equation High
# ===============================================================================
#                   coefficient       std. error           t-stat            prob
# -------------------------------------------------------------------------------
# const                0.001795         0.016775            0.107           0.915
# L1.Open              0.442961         0.223036            1.986           0.047
# L1.High             -1.130843         0.224910           -5.028           0.000
# L1.Low               0.048978         0.211932            0.231           0.817
# L1.Close             0.178085         0.427132            0.417           0.677
# L1.Adj Close         0.522630         0.388844            1.344           0.179
# L1.Volume            0.000001         0.000001            0.513           0.608
# L2.Open              0.364074         0.237286            1.534           0.125
# L2.High             -0.550832         0.255261           -2.158           0.031
# L2.Low              -0.185702         0.238653           -0.778           0.436
# L2.Close            -0.137556         0.436334           -0.315           0.753
# L2.Adj Close         0.477589         0.395541            1.207           0.227
# L2.Volume           -0.000001         0.000001           -0.551           0.582
# L3.Open              0.222159         0.212321            1.046           0.295
# L3.High             -0.433559         0.236628           -1.832           0.067
# L3.Low               0.073787         0.208622            0.354           0.724
# L3.Close             0.493398         0.429040            1.150           0.250
# L3.Adj Close        -0.297539         0.395344           -0.753           0.452
# L3.Volume           -0.000001         0.000001           -0.576           0.565
# ===============================================================================
#
# Results for equation Low
# ===============================================================================
#                   coefficient       std. error           t-stat            prob
# -------------------------------------------------------------------------------
# const               -0.000963         0.017824           -0.054           0.957
# L1.Open              0.506774         0.236986            2.138           0.032
# L1.High             -0.394299         0.238977           -1.650           0.099
# L1.Low              -0.648994         0.225188           -2.882           0.004
# L1.Close             0.454080         0.453848            1.001           0.317
# L1.Adj Close         0.153735         0.413165            0.372           0.710
# L1.Volume            0.000001         0.000001            0.479           0.632
# L2.Open              0.564149         0.252127            2.238           0.025
# L2.High             -0.362440         0.271227           -1.336           0.181
# L2.Low              -0.714730         0.253580           -2.819           0.005
# L2.Close             0.093881         0.463626            0.202           0.840
# L2.Adj Close         0.435309         0.420281            1.036           0.300
# L2.Volume           -0.000001         0.000002           -0.857           0.391
# L3.Open              0.192611         0.225601            0.854           0.393
# L3.High             -0.316788         0.251428           -1.260           0.208
# L3.Low              -0.115229         0.221670           -0.520           0.603
# L3.Close             0.190077         0.455875            0.417           0.677
# L3.Adj Close         0.056631         0.420072            0.135           0.893
# L3.Volume           -0.000002         0.000001           -1.268           0.205
# ===============================================================================
#
# Results for equation Close
# ===============================================================================
#                   coefficient       std. error           t-stat            prob
# -------------------------------------------------------------------------------
# const                0.000711         0.018067            0.039           0.969
# L1.Open              0.330562         0.240222            1.376           0.169
# L1.High             -0.213258         0.242240           -0.880           0.379
# L1.Low               0.211929         0.228263            0.928           0.353
# L1.Close            -0.371790         0.460045           -0.808           0.419
# L1.Adj Close         0.110538         0.418806            0.264           0.792
# L1.Volume            0.000000         0.000001            0.378           0.705
# L2.Open              0.169609         0.255570            0.664           0.507
# L2.High              0.208605         0.274930            0.759           0.448
# L2.Low              -0.026697         0.257042           -0.104           0.917
# L2.Close            -0.774743         0.469956           -1.649           0.099
# L2.Adj Close         0.378753         0.426020            0.889           0.374
# L2.Volume           -0.000002         0.000002           -1.452           0.147
# L3.Open              0.029407         0.228681            0.129           0.898
# L3.High             -0.062032         0.254861           -0.243           0.808
# L3.Low               0.232272         0.224697            1.034           0.301
# L3.Close            -0.218272         0.462099           -0.472           0.637
# L3.Adj Close         0.060945         0.425807            0.143           0.886
# L3.Volume           -0.000001         0.000001           -1.023           0.306
# ===============================================================================
#
# Results for equation Adj Close
# ===============================================================================
#                   coefficient       std. error           t-stat            prob
# -------------------------------------------------------------------------------
# const                0.003372         0.017689            0.191           0.849
# L1.Open              0.338426         0.235194            1.439           0.150
# L1.High             -0.216419         0.237169           -0.913           0.362
# L1.Low               0.199907         0.223485            0.895           0.371
# L1.Close            -0.359551         0.450415           -0.798           0.425
# L1.Adj Close         0.108319         0.410040            0.264           0.792
# L1.Volume            0.000000         0.000001            0.378           0.705
# L2.Open              0.174672         0.250220            0.698           0.485
# L2.High              0.198641         0.269175            0.738           0.461
# L2.Low              -0.029020         0.251662           -0.115           0.908
# L2.Close            -0.766235         0.460119           -1.665           0.096
# L2.Adj Close         0.372474         0.417102            0.893           0.372
# L2.Volume           -0.000002         0.000001           -1.504           0.133
# L3.Open              0.057344         0.223894            0.256           0.798
# L3.High             -0.082644         0.249527           -0.331           0.740
# L3.Low               0.224169         0.219994            1.019           0.308
# L3.Close            -0.211803         0.452427           -0.468           0.640
# L3.Adj Close         0.060958         0.416894            0.146           0.884
# L3.Volume           -0.000001         0.000001           -1.065           0.287
# ===============================================================================
#
# Results for equation Volume
# ===============================================================================
#                   coefficient       std. error           t-stat            prob
# -------------------------------------------------------------------------------
# const              -42.223576       915.027512           -0.046           0.963
# L1.Open          -4979.220041     12166.175319           -0.409           0.682
# L1.High          -4953.235141     12268.377674           -0.404           0.686
# L1.Low            1710.154672     11560.492178            0.148           0.882
# L1.Close         -6288.408734     23299.236184           -0.270           0.787
# L1.Adj Close     12074.110721     21210.681428            0.569           0.569
# L1.Volume           -0.774629         0.065276          -11.867           0.000
# L2.Open          -6749.743084     12943.474672           -0.521           0.602
# L2.High          -9592.492310     13923.984218           -0.689           0.491
# L2.Low            1085.810667     13018.039653            0.083           0.934
# L2.Close          7426.779999     23801.189912            0.312           0.755
# L2.Adj Close      6021.561274     21576.014085            0.279           0.780
# L2.Volume           -0.435035         0.077085           -5.644           0.000
# L3.Open           7753.037336     11581.673629            0.669           0.503
# L3.High         -10237.202094     12907.597353           -0.793           0.428
# L3.Low           -8593.005793     11379.901877           -0.755           0.450
# L3.Close         12174.517336     23403.275994            0.520           0.603
# L3.Adj Close      1450.427472     21565.250584            0.067           0.946
# L3.Volume           -0.175563         0.065964           -2.662           0.008
# ===============================================================================
#
# Correlation matrix of residuals
#                  Open      High       Low     Close  Adj Close    Volume
# Open         1.000000  0.835413  0.914235  0.750009   0.741051 -0.057401
# High         0.835413  1.000000  0.809692  0.912676   0.902572  0.007913
# Low          0.914235  0.809692  1.000000  0.845007   0.833422 -0.046002
# Close        0.750009  0.912676  0.845007  1.000000   0.987148 -0.024664
# Adj Close    0.741051  0.902572  0.833422  0.987148   1.000000 -0.025085
# Volume      -0.057401  0.007913 -0.046002 -0.024664  -0.025085  1.000000

# %%
# Durbin Watson Statistic 
out = durbin_watson(res_DAX.resid)
for col,val in zip(concat_data_DAX.columns,out):
    print((col), ':', round(val,2))
# Out:
# Open : 2.03
# High : 2.02
# Low : 1.96
# Close : 2.01
# Adj Close : 2.01
# Volume : 2.06

# %%
# haciendo el forecast de los datos
pred_DAX = res_DAX.forecast(concat_data_DAX.values[-30:],30)
pred_df_DAX = pd.DataFrame(pred_DAX,index=concat_data_DAX.index[-30:],columns=concat_data_DAX.columns)
pred_df_DAX
# Out:
#                 Open      High       Low     Close  Adj Close       Volume
# Date
# 2020-01-22  0.236250  0.478722 -0.022053  0.271098   0.277128  -175.133169
# 2020-01-23  0.009215 -0.196099 -0.113627 -0.303074  -0.288241  6829.293265
# 2020-01-24  0.130525  0.117425  0.183891  0.202407   0.198591 -5405.854319
# 2020-01-27 -0.094121 -0.001740 -0.022649  0.006162   0.009317   -55.206785
# 2020-01-28  0.030726 -0.003047 -0.025093 -0.038516  -0.033473  1504.411291
# 2020-01-29  0.020362  0.004932  0.004080  0.015099   0.018675  1133.930249
# 2020-01-30 -0.011940  0.002727  0.018251  0.014717   0.015317 -2675.461096
# 2020-01-31  0.012392  0.009403  0.000451 -0.008162  -0.004792  1454.260676
# 2020-02-03 -0.003158 -0.004466 -0.007546  0.002051   0.005156   241.082377
# 2020-02-04  0.003117  0.007313  0.007259  0.009296   0.011558  -656.373931
# 2020-02-05  0.004712  0.002354  0.001141 -0.002775  -0.000022   139.656016
# 2020-02-06  0.002567  0.001355  0.001211  0.001569   0.004236   250.681451
# 2020-02-07  0.001109  0.004238  0.002011  0.005501   0.008095  -215.111877
# 2020-02-10  0.003388  0.002897  0.001268  0.000541   0.003253     7.882707
# 2020-02-11  0.002947  0.002268  0.001564  0.001796   0.004459    72.585742
# 2020-02-12  0.002265  0.003195  0.002072  0.003150   0.005758   -43.833180
# 2020-02-13  0.002639  0.003072  0.001470  0.002013   0.004685   -17.814258
# 2020-02-14  0.002794  0.002684  0.001474  0.001925   0.004594    24.872776
# 2020-02-18  0.002508  0.002940  0.001790  0.002553   0.005193   -16.152049
# 2020-02-19  0.002666  0.002976  0.001675  0.002195   0.004848    -8.115197
# 2020-02-20  0.002669  0.002846  0.001559  0.002128   0.004789     4.966895
# 2020-02-21  0.002594  0.002900  0.001667  0.002327   0.004977    -6.642929
# 2020-02-24  0.002634  0.002934  0.001664  0.002254   0.004907    -6.190540
# 2020-02-25  0.002655  0.002883  0.001623  0.002192   0.004848    -0.385985
# 2020-02-26  0.002621  0.002901  0.001646  0.002267   0.004920    -4.238295
# 2020-02-27  0.002629  0.002912  0.001649  0.002250   0.004904    -4.832282
# 2020-02-28  0.002641  0.002899  0.001638  0.002227   0.004882    -2.619294
# 2020-03-02  0.002631  0.002900  0.001643  0.002247   0.004901    -3.543860
# 2020-03-03  0.002631  0.002906  0.001645  0.002247   0.004901    -4.115605
# 2020-03-04  0.002635  0.002902  0.001641  0.002237   0.004891    -3.348036

# %%
# haciendo la suma acumulativa de los datos para volverlos no estacionarios de nuevo
pred_inverse_DAX = pred_df_DAX.cumsum()
pred_inverse_DAX
# Out:
#                 Open      High       Low     Close  Adj Close       Volume
# Date
# 2020-01-22  0.236250  0.478722 -0.022053  0.271098   0.277128  -175.133169
# 2020-01-23  0.245465  0.282624 -0.135680 -0.031976  -0.011113  6654.160096
# 2020-01-24  0.375990  0.400048  0.048211  0.170431   0.187477  1248.305778
# 2020-01-27  0.281869  0.398309  0.025562  0.176593   0.196795  1193.098993
# 2020-01-28  0.312595  0.395262  0.000469  0.138078   0.163322  2697.510284
# 2020-01-29  0.332957  0.400194  0.004549  0.153177   0.181997  3831.440533
# 2020-01-30  0.321017  0.402920  0.022800  0.167894   0.197314  1155.979437
# 2020-01-31  0.333408  0.412323  0.023251  0.159732   0.192522  2610.240113
# 2020-02-03  0.330251  0.407857  0.015705  0.161783   0.197678  2851.322490
# 2020-02-04  0.333368  0.415170  0.022964  0.171079   0.209236  2194.948559
# 2020-02-05  0.338080  0.417525  0.024105  0.168303   0.209213  2334.604575
# 2020-02-06  0.340647  0.418879  0.025316  0.169872   0.213449  2585.286027
# 2020-02-07  0.341756  0.423117  0.027327  0.175373   0.221545  2370.174150
# 2020-02-10  0.345143  0.426014  0.028595  0.175915   0.224798  2378.056857
# 2020-02-11  0.348090  0.428282  0.030159  0.177711   0.229257  2450.642600
# 2020-02-12  0.350355  0.431477  0.032231  0.180861   0.235014  2406.809420
# 2020-02-13  0.352993  0.434549  0.033701  0.182874   0.239699  2388.995162
# 2020-02-14  0.355787  0.437233  0.035175  0.184799   0.244293  2413.867938
# 2020-02-18  0.358295  0.440174  0.036965  0.187352   0.249486  2397.715889
# 2020-02-19  0.360961  0.443150  0.038640  0.189548   0.254335  2389.600692
# 2020-02-20  0.363630  0.445996  0.040199  0.191676   0.259123  2394.567588
# 2020-02-21  0.366223  0.448896  0.041866  0.194002   0.264100  2387.924659
# 2020-02-24  0.368858  0.451830  0.043530  0.196256   0.269007  2381.734119
# 2020-02-25  0.371513  0.454713  0.045153  0.198448   0.273855  2381.348134
# 2020-02-26  0.374134  0.457614  0.046798  0.200715   0.278775  2377.109839
# 2020-02-27  0.376762  0.460526  0.048447  0.202966   0.283679  2372.277557
# 2020-02-28  0.379403  0.463425  0.050085  0.205193   0.288561  2369.658264
# 2020-03-02  0.382034  0.466325  0.051728  0.207440   0.293462  2366.114404
# 2020-03-03  0.384665  0.469231  0.053373  0.209687   0.298362  2361.998799
# 2020-03-04  0.387300  0.472133  0.055014  0.211924   0.303253  2358.650762

# %%
X_test_DAX = X_test_DAX.set_index('Date')

# %%
# haciendo el forecast con los datos de test
f_DAX = pred_inverse_DAX + X_test_DAX
f_DAX = f_DAX.dropna()

# %%
# Ploteo de la prediccion contra el real de los datos usando 15 dias
plt.figure(figsize=(12,12))
ax = plt.axes()
ax.set_facecolor('grey')
ax1= X_test_DAX.Open.plot(c='blue',grid=True, label='Open Price')
ax2= f_DAX.Open.plot(c='yellow', ls='--',grid=True,secondary_y=True,label='Precio Open Original')
ax1.legend(loc='lower left')
ax2.legend()
plt.savefig('../images/RealvsPredDAX.png')
plt.show()

# %%
# muestra de los datos predecidos
f_DAX
# Out:
#                  Open       High        Low      Close  Adj Close  \
# Date
# 2020-02-12  28.710356  28.991476  28.282231  28.635861  28.690014
# 2020-02-13  28.812992  28.894548  28.308701  28.457874  28.514699
# 2020-02-14  28.755787  28.837233  28.300174  28.449798  28.509292
# 2020-02-18  28.468296  28.640175  28.096964  28.247351  28.309485
# 2020-02-19  28.480962  28.691149  28.158641  28.429548  28.494335
# 2020-02-20  28.663629  28.745995  27.980200  28.131677  28.199124
# 2020-02-21  28.308222  28.390895  27.880867  28.114002  28.184100
# 2020-02-24  27.168857  27.320829  26.257531  27.011257  27.084008
# 2020-02-25  27.171512  27.254712  26.169154  26.348448  26.423855
# 2020-02-26  26.634134  26.921615  26.146798  26.370715  26.448775
# 2020-02-27  25.996763  26.463526  25.258446  25.412965  25.493678
# 2020-02-28  24.889403  25.458426  24.523085  25.155194  25.238562
# 2020-03-02  25.472034  25.886325  24.956729  25.567441  25.653463
# 2020-03-03  26.104664  26.219231  25.053373  25.300687  25.389362
# 2020-03-04  25.957300  26.082134  25.625014  25.821925  25.913254
#
#                   Volume
# Date
# 2020-02-12   7306.809420
# 2020-02-13   3188.995162
# 2020-02-14   5013.867938
# 2020-02-18   4897.715889
# 2020-02-19   3689.600692
# 2020-02-20   4194.567588
# 2020-02-21   3287.924659
# 2020-02-24   7281.734119
# 2020-02-25  19281.348134
# 2020-02-26   5677.109839
# 2020-02-27  13072.277557
# 2020-02-28   8769.658264
# 2020-03-02   5966.114404
# 2020-03-03   7261.998799
# 2020-03-04   2823.650762

# %%
# evaluacion del forecast
forecast_errors = [X_test_DAX.Open[i]-f_DAX.Open[i] for i in range(len(X_test_DAX.Open))]
bias = sum(forecast_errors)* 1.0/len(X_test_DAX.Open)
print(bias)
# Out:
# -0.3688609260255324

# %%
mae = mean_absolute_error(X_test_DAX.Open,f_DAX.Open)
mse = mean_squared_error(X_test_DAX.Open, f_DAX.Open)
print('Mean abosolute error: ',mae,'mean squared error: ', mse )
# Out:
# Mean abosolute error:  0.3688609260255324 mean squared error:  0.13618806760270244

# %% [markdown]
# # SMT VAR para VOO

# %%
mod_VOO = smt.VAR(concat_data_VOO)
res_VOO = mod_VOO.fit(maxlags=3)
print(res_VOO.summary())
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Thu, 05, Mar, 2020
# Time:                     16:02:41
# --------------------------------------------------------------------
# No. of Equations:         6.00000    BIC:                    27.5056
# Nobs:                     250.000    HQIC:                   26.5461
# Log likelihood:          -5251.89    FPE:                1.77391e+11
# AIC:                      25.8999    Det(Omega_mle):     1.14303e+11
# --------------------------------------------------------------------
# Results for equation Open
# ===============================================================================
#                   coefficient       std. error           t-stat            prob
# -------------------------------------------------------------------------------
# const                0.043440         0.115854            0.375           0.708
# L1.Open             -0.602012         0.155518           -3.871           0.000
# L1.High             -0.141544         0.172121           -0.822           0.411
# L1.Low              -0.138497         0.154356           -0.897           0.370
# L1.Close             0.931414         0.675316            1.379           0.168
# L1.Adj Close         0.114700         0.659681            0.174           0.862
# L1.Volume           -0.000000         0.000000           -2.526           0.012
# L2.Open             -0.553145         0.170844           -3.238           0.001
# L2.High              0.019043         0.199715            0.095           0.924
# L2.Low               0.091819         0.164433            0.558           0.577
# L2.Close             0.396478         0.676561            0.586           0.558
# L2.Adj Close         0.161984         0.660735            0.245           0.806
# L2.Volume           -0.000000         0.000000           -1.810           0.070
# L3.Open             -0.179441         0.143745           -1.248           0.212
# L3.High             -0.255512         0.183252           -1.394           0.163
# L3.Low               0.203424         0.154559            1.316           0.188
# L3.Close            -0.410245         0.667012           -0.615           0.539
# L3.Adj Close         0.878611         0.658026            1.335           0.182
# L3.Volume            0.000000         0.000000            1.691           0.091
# ===============================================================================
#
# Results for equation High
# ===============================================================================
#                   coefficient       std. error           t-stat            prob
# -------------------------------------------------------------------------------
# const                0.159562         0.116772            1.366           0.172
# L1.Open              0.130815         0.156750            0.835           0.404
# L1.High             -1.071529         0.173484           -6.177           0.000
# L1.Low              -0.105436         0.155578           -0.678           0.498
# L1.Close             1.498933         0.680663            2.202           0.028
# L1.Adj Close        -0.479517         0.664904           -0.721           0.471
# L1.Volume           -0.000000         0.000000           -1.476           0.140
# L2.Open             -0.018477         0.172197           -0.107           0.915
# L2.High             -0.750117         0.201297           -3.726           0.000
# L2.Low               0.130152         0.165735            0.785           0.432
# L2.Close             0.570509         0.681918            0.837           0.403
# L2.Adj Close         0.030062         0.665967            0.045           0.964
# L2.Volume           -0.000000         0.000000           -1.135           0.256
# L3.Open              0.006233         0.144883            0.043           0.966
# L3.High             -0.509046         0.184703           -2.756           0.006
# L3.Low               0.252451         0.155783            1.621           0.105
# L3.Close            -0.032272         0.672293           -0.048           0.962
# L3.Adj Close         0.443364         0.663236            0.668           0.504
# L3.Volume            0.000000         0.000000            0.885           0.376
# ===============================================================================
#
# Results for equation Low
# ===============================================================================
#                   coefficient       std. error           t-stat            prob
# -------------------------------------------------------------------------------
# const                0.108414         0.147772            0.734           0.463
# L1.Open              0.306609         0.198363            1.546           0.122
# L1.High             -0.404680         0.219539           -1.843           0.065
# L1.Low              -0.686281         0.196879           -3.486           0.000
# L1.Close             1.228893         0.861361            1.427           0.154
# L1.Adj Close        -0.348837         0.841419           -0.415           0.678
# L1.Volume           -0.000000         0.000000           -2.133           0.033
# L2.Open              0.027038         0.217910            0.124           0.901
# L2.High             -0.351978         0.254736           -1.382           0.167
# L2.Low              -0.275883         0.209733           -1.315           0.188
# L2.Close             0.457494         0.862949            0.530           0.596
# L2.Adj Close         0.084640         0.842763            0.100           0.920
# L2.Volume           -0.000000         0.000000           -2.272           0.023
# L3.Open             -0.070834         0.183345           -0.386           0.699
# L3.High             -0.422192         0.233737           -1.806           0.071
# L3.Low               0.106020         0.197139            0.538           0.591
# L3.Close             0.331961         0.850769            0.390           0.696
# L3.Adj Close         0.182905         0.839307            0.218           0.827
# L3.Volume           -0.000000         0.000000           -0.002           0.998
# ===============================================================================
#
# Results for equation Close
# ===============================================================================
#                   coefficient       std. error           t-stat            prob
# -------------------------------------------------------------------------------
# const                0.208690         0.162450            1.285           0.199
# L1.Open              0.320523         0.218066            1.470           0.142
# L1.High             -0.800198         0.241346           -3.316           0.001
# L1.Low               0.027394         0.216436            0.127           0.899
# L1.Close             1.116922         0.946921            1.180           0.238
# L1.Adj Close        -0.836270         0.924998           -0.904           0.366
# L1.Volume           -0.000000         0.000000           -0.236           0.813
# L2.Open              0.033257         0.239556            0.139           0.890
# L2.High             -0.734250         0.280039           -2.622           0.009
# L2.Low               0.385801         0.230566            1.673           0.094
# L2.Close             0.119957         0.948666            0.126           0.899
# L2.Adj Close         0.064365         0.926476            0.069           0.945
# L2.Volume           -0.000000         0.000000           -1.068           0.286
# L3.Open             -0.056790         0.201557           -0.282           0.778
# L3.High             -0.582982         0.256954           -2.269           0.023
# L3.Low               0.396600         0.216721            1.830           0.067
# L3.Close             0.318733         0.935277            0.341           0.733
# L3.Adj Close        -0.010080         0.922677           -0.011           0.991
# L3.Volume            0.000000         0.000000            0.200           0.841
# ===============================================================================
#
# Results for equation Adj Close
# ===============================================================================
#                   coefficient       std. error           t-stat            prob
# -------------------------------------------------------------------------------
# const                0.226949         0.161880            1.402           0.161
# L1.Open              0.321412         0.217302            1.479           0.139
# L1.High             -0.793773         0.240500           -3.301           0.001
# L1.Low               0.018405         0.215677            0.085           0.932
# L1.Close             1.109692         0.943600            1.176           0.240
# L1.Adj Close        -0.822153         0.921754           -0.892           0.372
# L1.Volume           -0.000000         0.000000           -0.184           0.854
# L2.Open              0.048384         0.238715            0.203           0.839
# L2.High             -0.718354         0.279057           -2.574           0.010
# L2.Low               0.358444         0.229758            1.560           0.119
# L2.Close             0.107817         0.945340            0.114           0.909
# L2.Adj Close         0.079197         0.923227            0.086           0.932
# L2.Volume           -0.000000         0.000000           -1.030           0.303
# L3.Open             -0.043869         0.200850           -0.218           0.827
# L3.High             -0.588022         0.256053           -2.296           0.022
# L3.Low               0.382567         0.215961            1.771           0.076
# L3.Close             0.361853         0.931998            0.388           0.698
# L3.Adj Close        -0.050512         0.919441           -0.055           0.956
# L3.Volume            0.000000         0.000000            0.190           0.849
# ===============================================================================
#
# Results for equation Volume
# ===============================================================================
#                   coefficient       std. error           t-stat            prob
# -------------------------------------------------------------------------------
# const            46138.657899     88796.143041            0.520           0.603
# L1.Open        -339381.069477    119196.404267           -2.847           0.004
# L1.High         304021.254083    131921.209966            2.305           0.021
# L1.Low          201244.552038    118305.121592            1.701           0.089
# L1.Close         52289.485307    517592.981567            0.101           0.920
# L1.Adj Close   -359588.787812    505609.615520           -0.711           0.477
# L1.Volume           -0.394550         0.077403           -5.097           0.000
# L2.Open         -99200.939424    130942.546321           -0.758           0.449
# L2.High         329712.083028    153070.969581            2.154           0.031
# L2.Low          185070.892833    126029.033753            1.468           0.142
# L2.Close       -955373.392022    518547.056800           -1.842           0.065
# L2.Adj Close    637028.982220    506417.768208            1.258           0.208
# L2.Volume           -0.213792         0.089283           -2.395           0.017
# L3.Open          45956.900417    110172.400040            0.417           0.677
# L3.High         445266.355571    140452.802495            3.170           0.002
# L3.Low           25959.971299    118461.335214            0.219           0.827
# L3.Close       -283892.822120    511228.529122           -0.555           0.579
# L3.Adj Close   -306504.375158    504340.807196           -0.608           0.543
# L3.Volume           -0.387380         0.089718           -4.318           0.000
# ===============================================================================
#
# Correlation matrix of residuals
#                  Open      High       Low     Close  Adj Close    Volume
# Open         1.000000  0.838834  0.777126  0.596271   0.586221 -0.403972
# High         0.838834  1.000000  0.821723  0.794875   0.786103 -0.317636
# Low          0.777126  0.821723  1.000000  0.891708   0.886092 -0.516949
# Close        0.596271  0.794875  0.891708  1.000000   0.997347 -0.441315
# Adj Close    0.586221  0.786103  0.886092  0.997347   1.000000 -0.447820
# Volume      -0.403972 -0.317636 -0.516949 -0.441315  -0.447820  1.000000

# %%
X_train_VOO, X_test_VOO = VOO[0:-15], VOO[-15:]

# %%
X_test_VOO = X_test_VOO.set_index('Date')

# %%
out = durbin_watson(res_VOO.resid)
for col,val in zip(concat_data_VOO.columns,out):
    print((col), ':', round(val,2))
# Out:
# Open : 2.22
# High : 2.17
# Low : 2.07
# Close : 1.97
# Adj Close : 1.96
# Volume : 2.13

# %%
pred_VOO = res_VOO.forecast(concat_data_VOO.values[-30:],30)
pred_df_VOO = pd.DataFrame(pred_VOO,index=concat_data_VOO.index[-30:],columns=concat_data_VOO.columns)
pred_df_VOO
# Out:
#                 Open      High       Low     Close  Adj Close        Volume
# Date
# 2020-01-22  0.254339  4.229626  0.423892  2.672105   2.669879  8.818154e+06
# 2020-01-23 -0.550040  1.086423 -2.496860  1.519079   1.368305  4.807638e+06
# 2020-01-24  4.131227  2.721092  3.718826  2.383387   2.542837 -5.639369e+06
# 2020-01-27  2.467509 -0.296274  0.406180 -3.363694  -3.302012 -3.088688e+06
# 2020-01-28 -2.682533 -1.810119 -0.020574  0.398840   0.366860  8.352179e+05
# 2020-01-29 -0.972761  0.710638 -0.340500  1.489099   1.492100  3.691209e+06
# 2020-01-30  0.264002  0.391463 -1.173046 -0.178013  -0.155966  1.103865e+06
# 2020-01-31  1.364334  0.519954  0.898343  0.138304   0.187776 -3.021787e+06
# 2020-02-03  0.724924  0.098028  0.859082 -0.515344  -0.486008 -1.272673e+06
# 2020-02-04 -0.908477 -0.542281 -0.103413  0.098117   0.096761  1.315333e+06
# 2020-02-05 -0.571482  0.155458 -0.393158  0.664289   0.675324  1.585687e+06
# 2020-02-06  0.523725  0.526748 -0.172287  0.172394   0.197417 -1.590872e+05
# 2020-02-07  0.808410  0.321543  0.556934 -0.054893  -0.023202 -1.366546e+06
# 2020-02-10  0.184872 -0.043908  0.462378 -0.102207  -0.079705 -3.659235e+05
# 2020-02-11 -0.456415 -0.154491 -0.126706  0.158983   0.169274  8.958204e+05
# 2020-02-12 -0.122644  0.209801 -0.184960  0.377163   0.392159  6.472771e+05
# 2020-02-13  0.455424  0.372451  0.129330  0.145871   0.171032 -3.308936e+05
# 2020-02-14  0.426433  0.161554  0.347734 -0.036620  -0.010614 -6.313658e+05
# 2020-02-18  0.012501 -0.012833  0.203038  0.041327   0.060267  1.837503e+04
# 2020-02-19 -0.159344  0.045427 -0.038914  0.200628   0.215354  5.150949e+05
# 2020-02-20  0.085913  0.211727 -0.011036  0.227970   0.246915  2.218902e+05
# 2020-02-21  0.320585  0.236322  0.167023  0.102104   0.125711 -2.635041e+05
# 2020-02-24  0.227644  0.117939  0.225411  0.038154   0.060424 -2.524084e+05
# 2020-02-25  0.019819  0.056296  0.120814  0.106633   0.125038  1.174311e+05
# 2020-02-26 -0.001872  0.114007  0.026397  0.177223   0.194921  2.680000e+05
# 2020-02-27  0.145157  0.185844  0.068622  0.160824   0.181135  4.906364e+04
# 2020-02-28  0.225270  0.174438  0.157083  0.098924   0.120877 -1.536503e+05
# 2020-03-02  0.147069  0.113766  0.161832  0.084835   0.105495 -7.502431e+04
# 2020-03-03  0.054280  0.097535  0.098232  0.126402   0.145315  1.100844e+05
# 2020-03-04  0.074051  0.136238  0.066971  0.153630   0.172754  1.296150e+05

# %%
pred_inverse_VOO = pred_df_VOO.cumsum()
pred_inverse_VOO
# Out:
#                 Open       High       Low     Close  Adj Close        Volume
# Date
# 2020-01-22  0.254339   4.229626  0.423892  2.672105   2.669879  8.818154e+06
# 2020-01-23 -0.295701   5.316050 -2.072968  4.191184   4.038184  1.362579e+07
# 2020-01-24  3.835526   8.037141  1.645858  6.574571   6.581021  7.986423e+06
# 2020-01-27  6.303035   7.740868  2.052038  3.210877   3.279010  4.897735e+06
# 2020-01-28  3.620502   5.930749  2.031464  3.609716   3.645870  5.732953e+06
# 2020-01-29  2.647741   6.641386  1.690964  5.098815   5.137970  9.424162e+06
# 2020-01-30  2.911743   7.032849  0.517918  4.920802   4.982003  1.052803e+07
# 2020-01-31  4.276077   7.552803  1.416261  5.059106   5.169780  7.506239e+06
# 2020-02-03  5.001002   7.650832  2.275344  4.543763   4.683772  6.233567e+06
# 2020-02-04  4.092524   7.108550  2.171930  4.641880   4.780533  7.548900e+06
# 2020-02-05  3.521042   7.264008  1.778772  5.306169   5.455857  9.134587e+06
# 2020-02-06  4.044767   7.790756  1.606485  5.478563   5.653273  8.975499e+06
# 2020-02-07  4.853177   8.112299  2.163419  5.423669   5.630071  7.608954e+06
# 2020-02-10  5.038049   8.068391  2.625797  5.321462   5.550367  7.243030e+06
# 2020-02-11  4.581635   7.913901  2.499090  5.480445   5.719641  8.138851e+06
# 2020-02-12  4.458991   8.123701  2.314130  5.857608   6.111800  8.786128e+06
# 2020-02-13  4.914415   8.496152  2.443461  6.003479   6.282833  8.455234e+06
# 2020-02-14  5.340848   8.657707  2.791195  5.966859   6.272219  7.823868e+06
# 2020-02-18  5.353349   8.644874  2.994232  6.008186   6.332486  7.842243e+06
# 2020-02-19  5.194005   8.690300  2.955319  6.208814   6.547839  8.357338e+06
# 2020-02-20  5.279918   8.902027  2.944282  6.436784   6.794754  8.579228e+06
# 2020-02-21  5.600502   9.138350  3.111305  6.538888   6.920465  8.315724e+06
# 2020-02-24  5.828147   9.256289  3.336716  6.577042   6.980889  8.063316e+06
# 2020-02-25  5.847966   9.312585  3.457529  6.683676   7.105927  8.180747e+06
# 2020-02-26  5.846093   9.426591  3.483927  6.860898   7.300848  8.448747e+06
# 2020-02-27  5.991250   9.612435  3.552549  7.021723   7.481982  8.497811e+06
# 2020-02-28  6.216521   9.786873  3.709632  7.120647   7.602859  8.344160e+06
# 2020-03-02  6.363589   9.900639  3.871464  7.205482   7.708355  8.269136e+06
# 2020-03-03  6.417869   9.998174  3.969696  7.331884   7.853670  8.379220e+06
# 2020-03-04  6.491920  10.134412  4.036667  7.485514   8.026424  8.508835e+06

# %%
f_VOO = pred_inverse_VOO + X_test_VOO
f_VOO = f_VOO.dropna()

# %%
f_VOO
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-02-12  314.018989  318.393690  311.484143  315.917606  316.171798
# 2020-02-13  313.514421  319.216153  310.803446  315.763489  316.042843
# 2020-02-14  315.450833  318.987694  311.791195  316.246858  316.552218
# 2020-02-18  314.593339  318.464881  311.024231  315.438179  315.762479
# 2020-02-19  315.614018  320.280296  313.075314  317.128827  317.467852
# 2020-02-20  315.629924  320.092029  309.614295  316.136796  316.494766
# 2020-02-21  313.900490  317.718337  308.731300  313.028878  313.410455
# 2020-02-24  302.788138  308.636294  298.506729  302.817032  303.220879
# 2020-02-25  303.577977  307.542596  289.817514  294.023672  294.445923
# 2020-02-26  294.456078  301.706590  288.963938  292.930905  293.370855
# 2020-02-27  286.561257  294.092446  276.912534  280.411738  280.871997
# 2020-02-28  271.536528  282.706886  265.959632  278.860637  279.342849
# 2020-03-02  280.363589  293.940648  274.361454  291.075477  291.578350
# 2020-03-03  290.757865  298.318181  277.329681  283.371893  283.893679
# 2020-03-04  287.721931  292.434400  282.736679  287.864512  288.405422
#
#                   Volume
# Date
# 2020-02-12  1.090193e+07
# 2020-02-13  1.049863e+07
# 2020-02-14  9.460868e+06
# 2020-02-18  1.084254e+07
# 2020-02-19  1.061484e+07
# 2020-02-20  1.319653e+07
# 2020-02-21  1.099372e+07
# 2020-02-24  1.516032e+07
# 2020-02-25  1.664655e+07
# 2020-02-26  1.868245e+07
# 2020-02-27  2.339481e+07
# 2020-02-28  3.166826e+07
# 2020-03-02  2.069774e+07
# 2020-03-03  1.814562e+07
# 2020-03-04  1.015522e+07

# %%
fig = plt.figure(figsize=(12,12))
ax = plt.axes()
ax.set_facecolor('grey')
ax1= X_test_VOO['Open'].plot(c='blue',grid=True, label='Open Price')
ax2= f_VOO.Open.plot(c='yellow', ls='--',grid=True,secondary_y=True,label='Precio Open Original')
ax1.legend(loc='lower left')
ax2.legend()
plt.savefig('../images/RealvsPredVOO.png')
plt.show()

# %%
forecast_errors = [X_test_VOO.Open[i]-f_VOO.Open[i] for i in range(len(X_test_VOO.Open))]
bias = sum(forecast_errors)* 1.0/len(X_test_VOO.Open)
print(bias)
# Out:
# -5.676358951083474

# %%
mae = mean_absolute_error(X_test_VOO.Open,f_VOO.Open)
mse = mean_squared_error(X_test_VOO.Open, f_VOO.Open)
print('Mean abosolute error: ',mae,'mean squared error: ', mse )
# Out:
# Mean abosolute error:  5.676358951083474 mean squared error:  32.543352496138745
